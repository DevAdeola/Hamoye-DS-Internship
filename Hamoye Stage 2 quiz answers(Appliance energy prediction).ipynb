# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
plt.rcParams['figure.figsize'] = (20.0, 10.0)

# %%
# load in the data
df = pd.read_csv(r"C:\Users\Admin\Desktop\DA\Energy data.csv")

# %%
df.columns
# Out:
# Index(['date', 'Appliances', 'lights', 'T1', 'RH_1', 'T2', 'RH_2', 'T3',
#        'RH_3', 'T4', 'RH_4', 'T5', 'RH_5', 'T6', 'RH_6', 'T7', 'RH_7', 'T8',
#        'RH_8', 'T9', 'RH_9', 'T_out', 'Press_mm_hg', 'RH_out', 'Windspeed',
#        'Visibility', 'Tdewpoint', 'rv1', 'rv2'],
#       dtype='object')

# %%
# display the first 10 samples
df.head(5)
# Out:
#               date  Appliances  lights     T1       RH_1    T2       RH_2  \
# 0  1/11/2016 17:00          60      30  19.89  47.596667  19.2  44.790000
# 1  1/11/2016 17:10          60      30  19.89  46.693333  19.2  44.722500
# 2  1/11/2016 17:20          50      30  19.89  46.300000  19.2  44.626667
# 3  1/11/2016 17:30          50      40  19.89  46.066667  19.2  44.590000
# 4  1/11/2016 17:40          60      40  19.89  46.333333  19.2  44.530000
#
#       T3       RH_3         T4  ...         T9   RH_9  T_out  Press_mm_hg  \
# 0  19.79  44.730000  19.000000  ...  17.033333  45.53   6.60        733.5
# 1  19.79  44.790000  19.000000  ...  17.066667  45.56   6.48        733.6
# 2  19.79  44.933333  18.926667  ...  17.000000  45.50   6.37        733.7
# 3  19.79  45.000000  18.890000  ...  17.000000  45.40   6.25        733.8
# 4  19.79  45.000000  18.890000  ...  17.000000  45.40   6.13        733.9
#
#    RH_out  Windspeed  Visibility  Tdewpoint        rv1        rv2
# ...

# %%
# displays the total number of rows and columns respectively
df.shape
# Out:
# (19735, 29)

# %%
# we have no missing values in the dataset
df.isnull().sum()
# Out:
# date           0
# Appliances     0
# lights         0
# T1             0
# RH_1           0
# T2             0
# RH_2           0
# T3             0
# RH_3           0
# T4             0
# RH_4           0
# T5             0
# RH_5           0
# T6             0
# RH_6           0
# T7             0
# RH_7           0
# T8             0
# RH_8           0
# T9             0
# RH_9           0
# T_out          0
# Press_mm_hg    0
# RH_out         0
# Windspeed      0
# Visibility     0
# Tdewpoint      0
# rv1            0
# rv2            0
# dtype: int64

# %%
df.describe()
# Out:
#          Appliances        lights            T1          RH_1            T2  \
# count  19735.000000  19735.000000  19735.000000  19735.000000  19735.000000
# mean      97.694958      3.801875     21.686571     40.259739     20.341219
# std      102.524891      7.935988      1.606066      3.979299      2.192974
# min       10.000000      0.000000     16.790000     27.023333     16.100000
# 25%       50.000000      0.000000     20.760000     37.333333     18.790000
# 50%       60.000000      0.000000     21.600000     39.656667     20.000000
# 75%      100.000000      0.000000     22.600000     43.066667     21.500000
# max     1080.000000     70.000000     26.260000     63.360000     29.856667
#
#                RH_2            T3          RH_3            T4          RH_4  \
# count  19735.000000  19735.000000  19735.000000  19735.000000  19735.000000
# mean      40.420420     22.267611     39.242500     20.855335     39.026904
# ...

# %% [markdown]
# ## INSTRUCTIONS
#
# To answer some questions, you will need to normalize the dataset using the MinMaxScaler after removing the following columns: [“date”, “lights”]. The target variable is “Appliances”.
# Use a 70-30 train-test set split with a  random state of 42 (for reproducibility).
# Run a multiple linear regression using the training set and evaluate your model on the test set.

# %%
df.drop(['date', 'lights'], 1, inplace=True)

# %%
# this dataset failed independence assumption
sns.heatmap(df.corr(), annot=True)

# %%
# correlation of other variables with the target variable
df.corr()["Appliances"].abs().sort_values()
# Out:
# Visibility     0.000230
# RH_5           0.006955
# T9             0.010010
# rv2            0.011145
# rv1            0.011145
# Tdewpoint      0.015357
# RH_4           0.016965
# T5             0.019760
# T7             0.025801
# Press_mm_hg    0.034885
# RH_3           0.036292
# T8             0.039572
# T4             0.040281
# RH_9           0.051462
# T1             0.055447
# RH_7           0.055642
# RH_2           0.060465
# RH_6           0.083178
# T3             0.085060
# RH_1           0.086031
# Windspeed      0.087122
# RH_8           0.094039
# T_out          0.099155
# T6             0.117638
# T2             0.120073
# RH_out         0.152282
# Appliances     1.000000
# Name: Appliances, dtype: float64

# %%
from sklearn.model_selection import train_test_split 
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score, mean_absolute_error, mean_squared_error
from sklearn.linear_model import Ridge, Lasso 
from sklearn.preprocessing import MinMaxScaler

# %%
# normalise our dataset with MinMaxScaler
scaler = MinMaxScaler()
df = pd.DataFrame(scaler.fit_transform(df), columns=df.columns)

# %% [markdown]
# ##### PS: Questions 1 - 11 are objective questions

# %% [markdown]
# ## Q12
#
# From the dataset, fit a linear model on the relationship between the temperature in the living room in Celsius (x = T2) and the temperature outside the building (y = T6). What is the R^2 value in two D.P?

# %%
X1 = df[['T2']]
y1 = df['T6']

X_train, X_test, y_train, y_test = train_test_split(X1, y1, test_size= 0.30, random_state = 42)

lm = LinearRegression()

lm.fit(X_train, y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
pred= lm.predict(X_test)

# %%
r2_score = r2_score(y_test, pred)

# %%
r2_score
# Out:
# 0.6427789637100976

# %% [markdown]
# ## Q13
#
# What is the Mean Absolute Error (in two decimal places)?

# %%
#split the data into train and test size
X = df.drop(['Appliances'], 1)
y = df['Appliances']

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size= 0.30, random_state = 42)

# instantiate the classifier
clf = LinearRegression()

# %%
# fit the train and test data with the classifier
clf.fit(X_train, y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
predicted_values= clf.predict(X_test)

# %%
mae = mean_absolute_error(y_test, predicted_values)
print('MAE', round(mae, 2))
# Out:
# MAE 0.05

# %% [markdown]
# ## Q14
#
# What is the Residual Sum of Squares (in two decimal places)?

# %%
rss = np.sum(np.square(y_test - predicted_values))
print('RSS',round(rss, 2))
# Out:
# RSS 45.35

# %% [markdown]
# ## Q15
#
# What is the Root Mean Squared Error (in three decimal places)?

# %%
rmse = np.sqrt(mean_squared_error(y_test, predicted_values))
print('RMSE',round(rmse, 3))
# Out:
# RMSE 0.088

# %% [markdown]
# ## Q16
#
# What is the Coefficient of Determination (in two decimal places)?

# %%
r2_score = r2_score(y_test, predicted_values)
print('Coefficient of determination: ',round(r2_score, 2))
# Out:
# Coefficient of determination:  0.15

# %% [markdown]
# ## Q17
#
# Obtain the feature weights from your linear model above. Which features have the lowest and highest weights respectively?

# %%
linear_reg = clf 
linear_reg.fit(X_train, y_train)
linear_model_weights = get_weights_df(linear_reg, X_train, 'Linear_Model_Weight')
linear_model_weights
# Out:
#        Features  Linear_Model_Weight
# 0           rv1        -9.162493e+10
# 1          RH_2        -4.565923e-01
# 2         T_out        -3.220035e-01
# 3            T2        -2.361263e-01
# 4            T9        -1.899592e-01
# 5          RH_8        -1.575466e-01
# 6        RH_out        -7.777081e-02
# 7          RH_7        -4.462785e-02
# 8          RH_9        -3.982821e-02
# 9            T5        -1.564814e-02
# 10           T1        -3.241639e-03
# 11  Press_mm_hg         6.821431e-03
# 12           T7         1.036570e-02
# 13   Visibility         1.229985e-02
# 14         RH_5         1.600952e-02
# 15         RH_4         2.637979e-02
# 16           T4         2.892462e-02
# 17    Windspeed         2.915872e-02
# 18         RH_6         3.802594e-02
# 19         RH_3         9.604806e-02
# 20           T8         1.019794e-01
# 21    Tdewpoint         1.178578e-01
# 22           T6         2.364414e-01
# 23           T3         2.905535e-01
# ...

# %% [markdown]
# ## Q18
#
# Train a ridge regression model with an alpha value of 0.4. Is there any change to the root mean squared error (RMSE) when evaluated on the test set?

# %%
ridge_reg = Ridge(alpha=0.4)
ridge_reg.fit(X_train, y_train)
# Out:
# Ridge(alpha=0.4, copy_X=True, fit_intercept=True, max_iter=None,
#       normalize=False, random_state=None, solver='auto', tol=0.001)

# %%
# there is no change to the RMSE
ridge_rmse = np.sqrt(mean_squared_error(y_test, ridge_reg.predict(X_test)))
print('Ridge_RMSE',round(ridge_rmse, 3))
# Out:
# Ridge_RMSE 0.088

# %% [markdown]
# ## Q19
#
# Train a lasso regression model with an alpha value of 0.001 and obtain the new feature weights with it. How many of the features have non-zero feature weights?

# %%
lasso_reg = Lasso(alpha=0.001)
lasso_reg.fit(X_train, y_train)
# Out:
# Lasso(alpha=0.001, copy_X=True, fit_intercept=True, max_iter=1000,
#       normalize=False, positive=False, precompute=False, random_state=None,
#       selection='cyclic', tol=0.0001, warm_start=False)

# %%
# 4 features have non_zero weights
lasso_weights_df = get_weights_df(lasso_reg, X_train, 'Lasso_weight')
lasso_weights_df
# Out:
#        Features  Lasso_weight
# 0        RH_out     -0.049557
# 1          RH_8     -0.000110
# 2            T1      0.000000
# 3     Tdewpoint      0.000000
# 4    Visibility      0.000000
# 5   Press_mm_hg     -0.000000
# 6         T_out      0.000000
# 7          RH_9     -0.000000
# 8            T9     -0.000000
# 9            T8      0.000000
# 10         RH_7     -0.000000
# 11          rv1     -0.000000
# 12           T7     -0.000000
# 13           T6      0.000000
# 14         RH_5      0.000000
# 15           T5     -0.000000
# 16         RH_4      0.000000
# 17           T4     -0.000000
# 18         RH_3      0.000000
# 19           T3      0.000000
# 20         RH_2     -0.000000
# 21           T2      0.000000
# 22         RH_6     -0.000000
# 23          rv2     -0.000000
# 24    Windspeed      0.002912
# 25         RH_1      0.017880

# %% [markdown]
# ## Q20
#
# What is the new RMSE with the Lasso Regression (in 3 decimal places)?

# %%
lasso_rmse = np.sqrt(mean_squared_error(y_test, lasso_reg.predict(X_test)))
print('Lasso_RMSE',round(lasso_rmse, 3))
# Out:
# Lasso_RMSE 0.094
